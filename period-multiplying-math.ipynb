# %%
import sympy as sp

# %%
l1, l2, l3, l4, l5, l6 = sp.symbols(
    "lambda1, lambda2, lambda3, lambda4, lambda5, lambda6", real=False
)
l1 = sp.Rational(1)
# l2 = 1
# th = sp.Symbol("theta", real=True)
th = sp.pi / 5
l4 = sp.Rational(1)
l5 = 1 / l2
l3 = sp.cos(th) + sp.I * sp.sin(th)
l6 = sp.conjugate(l3)
lams = [l1, l2, l3, l4, l5, l6]
lams2 = [lam**2 for lam in lams]

# %%
alpha = 2 - sum(lams)
beta = (alpha**2 - (sum(lams2) - 2)) / 2

# %%
sp.simplify(beta)
# Out:
# (lambda2**2 + sqrt(5)*lambda2**2 + 4*lambda2 + 1 + sqrt(5))/(2*lambda2)

# %% [markdown]
# $$\beta=-\lambda-2\cos\theta-\frac{1}{\lambda+2}$$

# %%
sp.simplify(alpha)
# Out:
# -lambda2 - sqrt(5)/2 - 1/2 - 1/lambda2

# %%
alpha
# Out:
# -lambda1 - lambda2 + 2 - 1/lambda2 - 1/lambda1
