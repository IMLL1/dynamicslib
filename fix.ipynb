# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\imll1\Documents\CodeRepo\dynamicslib\Resonant 1-3 FIX ORDER.csv").set_index("Index")

# %%
df1 = df[df.index < 705]
df2 = df[df.index > 705]

# %%
df1
# Out:
#        Initial x  Initial vy     Period  Jacobi Constant  Stability Index  \
# Index
# 0       0.987317    6.771053  16.323628         2.729107       945.562249
# 1       0.987309    6.721073  16.326478         2.729788       939.926534
# 2       0.987301    6.671094  16.329358         2.730473       935.732016
# 3       0.987292    6.621115  16.332269         2.731165       929.496027
# 4       0.987284    6.571137  16.335211         2.731863       924.214939
# ...          ...         ...        ...              ...              ...
# 188     0.416310    1.625671  18.711253         2.184181         3.545327
# 189     0.413622    1.635261  18.713046         2.179589         3.523596
# 190     0.410952    1.644857  18.714812         2.175006         3.502332
# 191     0.408298    1.654459  18.716551         2.170431         3.481521
# 192     0.405661    1.664067  18.718264         2.165866         3.461150
#
# ...

# %%
df2
# Out:
#        Initial x  Initial vy     Period  Jacobi Constant  Stability Index  \
# Index
# 193     0.293999    2.150321  18.779015         1.950949         2.798608
# 194     0.295875    2.140508  18.778158         1.954962         2.807509
# 195     0.297764    2.130698  18.777289         1.958987         2.816522
# 196     0.299666    2.120890  18.776410         1.963024         2.825652
# 197     0.301582    2.111086  18.775519         1.967074         2.834900
# 198     0.303512    2.101284  18.774616         1.971136         2.844269
# 199     0.305455    2.091485  18.773702         1.975211         2.853762
# 200     0.307412    2.081690  18.772776         1.979298         2.863382
# 201     0.309383    2.071897  18.771838         1.983397         2.873133
# 202     0.311367    2.062107  18.770887         1.987508         2.883017
# 203     0.313366    2.052321  18.769924         1.991632         2.893038
# 204     0.315379    2.042538  18.768949         1.995768         2.903199
# ...

# %%
pd.concat((df1,df2)).to_csv("Resonant 1-3")
